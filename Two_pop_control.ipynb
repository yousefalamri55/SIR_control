# %%
import sys
sys.path.append('.')
from SIR_control_twopop import *

# %%
model_control('US')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 1.0 34.2767431758167 0.03553728165421086 2.0 68.5534863516334
# 500
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.27e-03       1.12e-04         10001           609
#        2          1.16e-06       1.44e-08         10610            0
# Solved in 2 iterations, number of nodes 10610.
# Maximum relative residual: 1.16e-06
# Maximum boundary residual: 1.44e-08
# The algorithm converged to the desired accuracy.
# 150 10610
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.80e-04       2.28e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.80e-04
# Maximum boundary residual: 2.28e-04
# The algorithm converged to the desired accuracy.
# 50 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.39e-03       9.71e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.39e-03
# Maximum boundary residual: 9.71e-04
# The algorithm converged to the desired accuracy.
# 20 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.58e-03       3.16e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.58e-03
# Maximum boundary residual: 3.16e-04
# The algorithm converged to the desired accuracy.
# 10 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.49e+00       7.22e-01         10001          3998
#        2          1.58e-03       7.23e-04         13999            0
# Solved in 2 iterations, number of nodes 13999.
# Maximum relative residual: 1.58e-03
# Maximum boundary residual: 7.23e-04
# The algorithm converged to the desired accuracy.
# 8 13999
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.77e-03       1.45e-03         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 2.77e-03
# Maximum boundary residual: 1.45e-03
# The algorithm converged to the desired accuracy.
# 5 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.84e-03       2.14e-02         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.84e-03
# Maximum boundary residual: 2.14e-02
# The algorithm converged to the desired accuracy.
# 3 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.88e-03       3.42e-02         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.88e-03
# Maximum boundary residual: 3.42e-02
# The algorithm converged to the desired accuracy.
# 2 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.01e-02       6.56e-02         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.01e-02
# Maximum boundary residual: 6.56e-02
# The algorithm converged to the desired accuracy.
# 1.4 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.44e-02       7.89e-02         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 4.44e-02
# Maximum boundary residual: 7.89e-02
# The algorithm converged to the desired accuracy.
# 1.2 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.06e-03       1.58e-03         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.06e-03
# Maximum boundary residual: 1.58e-03
# The algorithm converged to the desired accuracy.
# 1.1 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.26e-04       4.49e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 7.26e-04
# Maximum boundary residual: 4.49e-04
# The algorithm converged to the desired accuracy.
# 1
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          6.51e-05       1.10e-05         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 6.51e-05
# Maximum boundary residual: 1.10e-05
# The algorithm converged to the desired accuracy.
# 1.0 34.2767431758167 0.0017768640827105428 2.0 68.5534863516334
# 500
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.78e-02       2.28e-02         10001          10000
#        2          9.57e-07       2.58e-09         20001            0
# Solved in 2 iterations, number of nodes 20001.
# Maximum relative residual: 9.57e-07
# Maximum boundary residual: 2.58e-09
# The algorithm converged to the desired accuracy.
# 150 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.95e-02       5.12e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.95e-02
# Maximum boundary residual: 5.12e-04
# The algorithm converged to the desired accuracy.
# 50 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.17e-04       2.39e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.17e-04
# Maximum boundary residual: 2.39e-04
# The algorithm converged to the desired accuracy.
# 20 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.13e-03       6.70e-03         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 8.13e-03
# Maximum boundary residual: 6.70e-03
# The algorithm converged to the desired accuracy.
# 10 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.43e-03       4.08e-03         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.43e-03
# Maximum boundary residual: 4.08e-03
# The algorithm converged to the desired accuracy.
# 8 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.72e-03       1.04e-03         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 2.72e-03
# Maximum boundary residual: 1.04e-03
# The algorithm converged to the desired accuracy.
# 5 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.35e-03       1.25e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.35e-03
# Maximum boundary residual: 1.25e-04
# The algorithm converged to the desired accuracy.
# 3 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.45e-04       6.30e-05         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 9.45e-04
# Maximum boundary residual: 6.30e-05
# The algorithm converged to the desired accuracy.
# 2 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.02e-03       3.46e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.02e-03
# Maximum boundary residual: 3.46e-04
# The algorithm converged to the desired accuracy.
# 1.4 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.50e-03       3.53e-05         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.50e-03
# Maximum boundary residual: 3.53e-05
# The algorithm converged to the desired accuracy.
# 1.2 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.97e-03       7.55e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 3.97e-03
# Maximum boundary residual: 7.55e-04
# The algorithm converged to the desired accuracy.
# 1.1 10001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.12e-03       1.61e-04         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 1.12e-03
# Maximum boundary residual: 1.61e-04
# The algorithm converged to the desired accuracy.
# 1
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.92e-05       2.12e-05         10001            0
# Solved in 1 iterations, number of nodes 10001.
# Maximum relative residual: 7.92e-05
# Maximum boundary residual: 2.12e-05
# The algorithm converged to the desired accuracy.
# Estimated death toll with no further intervention: 2177580 + 821665
# Estimated death toll with optimal moderate intervention: 1058750 + 38540
# Estimated death toll with optimal srict intervention: 901118 + 33965

# %%
x10 = 0.68
x20 = 0.28
y10 = 0.01
y20 = 0.01
c1 = 0.5
c2 = 1.0
c3 = 5.e-3
c4 = 1.
c5 = 1.
T = 200
x1, x2, y1, y2, q1, q2, t = optimal_intervention(x10,x20,y10,y20,c1,c2,c3,c4,c5,T=T,
                                                 multipliers=(500,50,20,10,8,5,4.5,4,3,2,1.4,1.2,1.1),
                                                 verbose=True,Nt=20000)
# Out:
# 0.5 1.0 0.005 1.0 1.0
# 500
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.83e-05       1.46e-06         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 1.83e-05
# Maximum boundary residual: 1.46e-06
# The algorithm converged to the desired accuracy.
# 50 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.73e-04       3.15e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 3.73e-04
# Maximum boundary residual: 3.15e-04
# The algorithm converged to the desired accuracy.
# 20 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.66e-04       1.03e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 9.66e-04
# Maximum boundary residual: 1.03e-03
# The algorithm converged to the desired accuracy.
# 10 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.44e-03       3.38e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 2.44e-03
# Maximum boundary residual: 3.38e-03
# The algorithm converged to the desired accuracy.
# 8 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.01e-03       4.96e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 1.01e-03
# Maximum boundary residual: 4.96e-04
# The algorithm converged to the desired accuracy.
# 5 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.29e-03       1.76e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 1.29e-03
# Maximum boundary residual: 1.76e-03
# The algorithm converged to the desired accuracy.
# 4.5 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.47e-04       3.81e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 4.47e-04
# Maximum boundary residual: 3.81e-04
# The algorithm converged to the desired accuracy.
# 4 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.89e-04       6.35e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 5.89e-04
# Maximum boundary residual: 6.35e-04
# The algorithm converged to the desired accuracy.
# 3 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.87e-03       5.92e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 3.87e-03
# Maximum boundary residual: 5.92e-03
# The algorithm converged to the desired accuracy.
# 2 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.51e-03       7.03e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 2.51e-03
# Maximum boundary residual: 7.03e-03
# The algorithm converged to the desired accuracy.
# 1.4 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.81e-03       7.72e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 1.81e-03
# Maximum boundary residual: 7.72e-03
# The algorithm converged to the desired accuracy.
# 1.2 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.41e-03       2.49e-03         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 1.41e-03
# Maximum boundary residual: 2.49e-03
# The algorithm converged to the desired accuracy.
# 1.1 20001
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.12e-04       7.97e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 5.12e-04
# Maximum boundary residual: 7.97e-04
# The algorithm converged to the desired accuracy.
# 1
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.13e-05       1.86e-04         20001            0
# Solved in 1 iterations, number of nodes 20001.
# Maximum relative residual: 4.13e-05
# Maximum boundary residual: 1.86e-04
# The algorithm converged to the desired accuracy.

# %%
fig = plot_timeline(x1,x2,y1,y2,q1,q2,t)

# %%
plt.plot(t,q1)

# %%
plt.plot(t,q2)
